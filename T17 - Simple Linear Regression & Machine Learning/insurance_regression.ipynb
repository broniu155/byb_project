# %%
"""
Program Name - insurance_regression.ipynb

Author: Tomasz Bronewicz
Latest Version: 1.0
Date: 06/05/2024

Changes: 
v1.0 - Initial version - Tomasz Broniewicz

============Description===========

Program that shows the linear regression 
of the insurance data

===================================
"""

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# Import the dataset
data = pd.read_csv("insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# select rows from the dataframe and reshape for plotting.  
x = data.iloc[:,:1].values.reshape(-1,1)
y = data.iloc[:,-1].values.reshape(-1,1)

# generate the plot
plt.scatter(x,y,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
# Fit the model
insurance = LinearRegression()
insurance.fit(x,y)
# Out:
# LinearRegression()

# %%
# Plot the data and model
pred = insurance.predict(x)

plt.scatter(x,y,color = 'b')
plt.plot(x,pred,color = 'r')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
